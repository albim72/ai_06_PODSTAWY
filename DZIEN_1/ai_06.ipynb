# %%
print("to jest pierwsza komórka")
# Out:
# to jest pierwsza komórka

# %%
a = 67
b = 17
a
# Out:
# 67

# %%
c = a+b  
d = 14
print(c*d)
print(a)
# Out:
# 1176
# 67

# %%
print(id(a))                                                              
print(id(c))
# Out:
# 126901615495336
# 126901615495880

# %%
v = a
print(id(v))
# Out:
# 126901615495336

# %%
g = 67
print(id(g))
# Out:
# 126901615495336

# %%
target = 67
aliases = [
    name for name,value in globals().items()
    if value is target
]
print(aliases)
# Out:
# ['_3', 'a', '_6', '_9', '_10', '_13', 'v', 'g', 'target']

# %%
def policz(e,h):
    return 10*e - 3*h

# %%
print(policz(1,1))
print(policz(0,4))
print(policz(12,0))
print(policz(-23,-2))
# Out:
# 7
# -12
# 120
# -224

# %%
class Osoba:
    def __init__(self,imie, nazwisko, wiek, wzrost):
        self.imie = imie
        self.nazwisko = nazwisko
        self.wiek = wiek
        self.wzrost = wzrost

    def info(self):
        return f"osoba: {self.imie} {self.nazwisko}, wiek: {self.wiek}, wzrost: {self.wzrost}"

# %%
os1 = Osoba("Jan","Kowalski",45,178)
print(os1.info())
# Out:
# osoba: Jan Kowalski, wiek: 45, wzrost: 178
